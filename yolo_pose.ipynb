# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('all_pose_data.csv')
data.head()
# Out:
#      class                 video  frame  track_id  frame_valid    kpt0_x  \
# 0  PullUps  v_Pullup_g01_c01.avi      1        -1            1  0.527683
# 1  PullUps  v_Pullup_g01_c01.avi      2        -1            1  0.528147
# 2  PullUps  v_Pullup_g01_c01.avi      3        -1            1  0.529285
# 3  PullUps  v_Pullup_g01_c01.avi      3        -1            1  0.524340
# 4  PullUps  v_Pullup_g01_c01.avi      4        -1            1  0.592095
#
#      kpt0_y  kpt0_conf    kpt1_x    kpt1_y  ...  kpt13_conf   kpt14_x  \
# 0  0.541908   0.878457  0.552925  0.519896  ...    0.042595  0.480293
# 1  0.526812   0.977107  0.549901  0.513626  ...    0.017612  0.475282
# 2  0.524921   0.720074  0.551841  0.504365  ...    0.023261  0.529129
# 3  0.526584   0.742671  0.549948  0.504847  ...    0.015906  0.457032
# 4  0.491487   0.296254  0.599038  0.470912  ...    0.026849  0.554110
#
#     kpt14_y  kpt14_conf   kpt15_x   kpt15_y  kpt15_conf   kpt16_x   kpt16_y  \
# 0  0.641447    0.036947  0.552620  0.679507    0.025023  0.583128  0.701049
# 1  0.662587    0.013899  0.557475  0.846681    0.002577  0.485492  0.822145
# 2  0.664121    0.016251  0.540558  0.775117    0.007324  0.546998  0.742991
# 3  0.634831    0.012997  0.535915  0.806089    0.003339  0.450418  0.769494
# 4  0.750070    0.019282  0.563745  0.808004    0.017888  0.566042  0.836535
#
#    kpt16_conf
# 0    0.021510
# 1    0.002404
# 2    0.006099
# 3    0.003134
# 4    0.013777
#
# [5 rows x 56 columns]

# %%
data.shape
# Out:
# (28476, 56)

# %%
tracked_data = data[data["track_id"] != -1].copy()

# %%
tracked_data = tracked_data.drop(tracked_data[tracked_data["frame_valid"] == 0].index)

# %%
tracked_data.shape
# Out:
# (26316, 56)

# %%
tracked_data.head()
# Out:
#       class                 video  frame  track_id  frame_valid    kpt0_x  \
# 39  PullUps  v_Pullup_g01_c01.avi      7         4            1  0.526088
# 40  PullUps  v_Pullup_g01_c01.avi      8         4            1  0.572025
# 41  PullUps  v_Pullup_g01_c01.avi      9         4            1  0.532492
# 42  PullUps  v_Pullup_g01_c01.avi     10         4            1  0.564332
# 43  PullUps  v_Pullup_g01_c01.avi     11         4            1  0.520871
#
#       kpt0_y  kpt0_conf    kpt1_x    kpt1_y  ...  kpt13_conf   kpt14_x  \
# 39  0.479043   0.918699  0.547763  0.470190  ...    0.019228  0.440400
# 40  0.489200   0.220292  0.574766  0.485169  ...    0.027499  0.541456
# 41  0.467502   0.751800  0.547638  0.455707  ...    0.015887  0.492614
# 42  0.437661   0.165362  0.565938  0.442883  ...    0.020283  0.536364
# 43  0.454179   0.923241  0.542102  0.446035  ...    0.015671  0.461379
#
#      kpt14_y  kpt14_conf   kpt15_x   kpt15_y  kpt15_conf   kpt16_x   kpt16_y  \
# 39  0.690555    0.018786  0.532351  0.778964    0.002266  0.456372  0.763230
# 40  0.879203    0.024883  0.479138  0.762059    0.001504  0.560725  0.850471
# 41  0.736532    0.014251  0.488137  0.824852    0.001001  0.501867  0.828970
# 42  0.687336    0.024501  0.498550  0.634825    0.004184  0.558362  0.701676
# 43  0.839078    0.015596  0.500996  0.835476    0.000956  0.468981  0.834197
#
#     kpt16_conf
# 39    0.002519
# 40    0.001298
# 41    0.000938
# 42    0.004582
# 43    0.001028
#
# [5 rows x 56 columns]

# %% [markdown]
# ## Dataset Cleaning

# %%
track_counts = (
    tracked_data.groupby(["video", "track_id"])
      .size()
      .reset_index(name="frame_count")
)

# %%
K = 1

track_counts = track_counts.sort_values(
    ["video", "frame_count"],
    ascending=[True, False]
)

track_counts["rank"] = (
    track_counts
    .groupby("video")
    .cumcount() + 1
)

track_counts["keep"] = track_counts["rank"] <= K

# %%
tracks_to_keep = track_counts[track_counts["keep"]][["video", "track_id"]]

df_filtered = tracked_data.merge(
    tracks_to_keep,
    on=["video", "track_id"],
    how="inner"
)

# %% [markdown]
# ## Dataset Preperation

# %%
class ActionCSVDataset(Dataset):
    def __init__(self, csv_file, seq_len=30):
        df = pd.read_csv(csv_file)
        self.seq_len = seq_len
        # Group by sequence_id to keep frames together
        self.sequences = []
        self.labels = []
        
        for _, group in df.groupby('sequence_id'):
            # Extract only the keypoint columns (kpt_0 to kpt_33)
            kpts = group.filter(like='kpt_').values
            if len(kpts) == seq_len:
                self.sequences.append(kpts)
                self.labels.append(group['label'].iloc[0])
        
        self.sequences = torch.tensor(self.sequences, dtype=torch.float32)
        self.labels = torch.tensor(self.labels, dtype=torch.long)

    def __len__(self): return len(self.labels)
    def __getitem__(self, idx): return self.sequences[idx], self.labels[idx]

# --- Training Setup ---
dataset = ActionCSVDataset('action_data.csv')
train_idx, test_idx = train_test_split(range(len(dataset)), test_size=0.1)
train_loader = DataLoader(torch.utils.data.Subset(dataset, train_idx), batch_size=16, shuffle=True)

# %% [markdown]
# ## Bi-LSTM Model

# %%
class BiLSTMActionModel(nn.Module):
    def __init__(self, input_size=34, hidden_size=64, num_layers=2, num_classes=2):
        super(BiLSTMActionModel, self).__init__()
        
        # Bi-LSTM Layer
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, 
                            batch_first=True, bidirectional=True, dropout=0.2)
        
        # Fully connected layer (Hidden * 2 because it's Bidirectional)
        self.fc = nn.Sequential(
            nn.Linear(hidden_size * 2, 32),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(32, num_classes)
        )
        
    def forward(self, x):
        # x shape: (batch, sequence_length, input_size)
        out, _ = self.lstm(x)
        
        # We only take the output from the last time step
        out = self.fc(out[:, -1, :])
        return out

# %% [markdown]
# ## Model Training

# %%
# Define Model (using the BiLSTMActionModel from before)
model = BiLSTMActionModel(input_size=34, num_classes=2)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# Training Loop
for epoch in range(150):
    for inputs, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
    print(f"Epoch {epoch+
# Epoch 83 Loss: 0.5777
# Epoch 84 Loss: 0.5680
# Epoch 85 Loss: 0.5466
# Epoch 86 Loss: 0.5521
# Epoch 87 Loss: 0.5503
# Epoch 88 Loss: 0.4533
# Epoch 89 Loss: 0.4245
# Epoch 90 Loss: 0.4497
# Epoch 91 Loss: 0.3850
# Epoch 92 Loss: 0.3954
# Epoch 93 Loss: 0.4342
# Epoch 94 Loss: 1.2965
# Epoch 95 Loss: 0.4319
# Epoch 96 Loss: 0.3866
# Epoch 97 Loss: 0.4136
# Epoch 98 Loss: 0.3927
# Epoch 99 Loss: 0.4228
# Epoch 100 Loss: 0.3866
# Epoch 101 Loss: 0.3810
# Epoch 102 Loss: 0.6002
# Epoch 103 Loss: 0.3681
# Epoch 104 Loss: 0.4019
# Epoch 105 Loss: 0.4184
# Epoch 106 Loss: 0.3947
# Epoch 107 Loss: 0.4243
# Epoch 108 Loss: 0.3812
# Epoch 109 Loss: 0.7945
# Epoch 110 Loss: 0.3966
# Epoch 111 Loss: 0.4193
# Epoch 112 Loss: 0.3641
# Epoch 113 Loss: 0.4252
# Epoch 114 Loss: 0.3444
# Epoch 115 Loss: 0.4074
# Epoch 116 Loss: 0.3970
# Epoch 117 Loss: 0.3944
# Epoch 118 Loss: 0.4043
# Epoch 119 Loss: 0.3792
# Epoch 120 Loss: 0.4135
# Epoch 121 Loss: 0.3937
# Epoch 122 Loss: 0.3901
# Epoch 123 Loss: 0.3978
# Epoch 124 Loss: 0.3823
# Epoch 125 Loss: 0.4064
# Epoch 126 Loss: 0.3818
# Epoch 127 Loss: 0.3757
# Epoch 128 Loss: 0.3982
# Epoch 129 Loss: 0.3519
# Epoch 130 Loss: 0.3837
# Epoch 131 Loss: 0.4086
# Epoch 132 Loss: 0.3806
# Epoch 133 Loss: 0.4073
# Epoch 134 Loss: 0.3573
# Epoch 135 Loss: 0.3997
# Epoch 136 Loss: 0.3814
# Epoch 137 Loss: 0.4020
# Epoch 138 Loss: 0.3796
# Epoch 139 Loss: 0.3681
# Epoch 140 Loss: 0.3882
# Epoch 141 Loss: 0.4062
# Epoch 142 Loss: 0.4136
# Epoch 143 Loss: 0.4070
# Epoch 144 Loss: 0.3983
# Epoch 145 Loss: 0.3949
# Epoch 146 Loss: 0.3847
# Epoch 147 Loss: 0.3986
# Epoch 148 Loss: 0.3549
# Epoch 149 Loss: 0.3741
# Epoch 150 Loss: 0.3747

# %%
# Create a dummy input that matches your input shape (Batch, Seq, Features)
dummy_input = torch.randn(1, 30, 34)

# Trace the model
traced_model = torch.jit.script(model, dummy_input)

# Save the serialized model
traced_model.save('action_model_jit.pt')
# Out:
# /tmp/ipykernel_89960/3259376625.py:5: FutureWarning: `optimize` is deprecated and has no effect. Use `with torch.jit.optimized_execution()` instead
#   traced_model = torch.jit.script(model, dummy_input)
